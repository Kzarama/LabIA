# %% [markdown]
# # Knapsack problem
#
# Given a list of items and a bag maximum capacity, find the best combination of items.
#
# The algorithm to complete:

# %%
import random
import math

class KnapsackGenetic:
  def __init__(self, params):
    self.ALL_NUMBERS = list(range(params["max_per_item"] + 1))
    self.params = params
    self.specimen = [None] * self.params["generation_size"]

    self.create_initial_population()

  def create_initial_population(self):
    self.specimen = list(map(
        lambda _: list(map(
            lambda _: random.choice(self.ALL_NUMBERS),
            [None] * len(self.params["items"])
        )),
        self.specimen
    ))

  def fitness(self, specimen):
    # Use params: self.params["max_weight"] to check the max weight of the specimen
    # Use params: self.params["items"]
    total_weight = 0
    total_value = 0
    for i in range(len(specimen)):
        total_weight += specimen[i] * self.params["items"][i].weight
    if total_weight > self.params["max_weight"]:
        return 1
    else:
        for i in range(len(specimen)):
            total_value += specimen[i] * self.params["items"][i].value
    return total_value

  def is_converged(self):
    if any(self.fitness(specimen) >= self.params["fit_threshold"] for specimen in self.specimen):
      return True

    return False

  def get_fit(self):
    evaluations = self.fitness_all()

    max_evaluation = max(evaluations)

    max_index = evaluations.index(max_evaluation)

    return self.specimen[max_index], max_evaluation

  def fitness_all(self):
    return list(map(self.fitness, self.specimen))

  def select_specimen(self, specimen_evaluations):
    specimen_and_evaluations = list(zip(self.specimen, specimen_evaluations))

    specimen_and_evaluations.sort(key=lambda e: e[1], reverse = True)

    n_top = int(math.ceil(len(self.specimen) * params["select_top"]))

    return list(map(lambda s: s[0], specimen_and_evaluations[:n_top]))
  
  def mutate(self, specimen):
    # Use parameter: self.params["max_per_item"] to check maximum for gene
    # Use parameter: self.params["mutation_percentage"]
    n_digits = int((len(specimen)) * params["mutation_percentage"]) 
    digit_indexes = random.sample( list(range(len(specimen))), n_digits)
    new_specimen = specimen[:]

    for i in digit_indexes:
        new_specimen[i] = random.choice(self.ALL_NUMBERS)

    return new_specimen
  
  def generate_children(self, selected_specimen):  
    mutated_specimen = [None] * len(self.specimen)

    for i in range(len(mutated_specimen)):
      mutated_specimen[i] = self.mutate(random.choice(selected_specimen))

    return mutated_specimen

  def run(self):
    generation_number = 1

    while generation_number <= self.params["max_generations"] and not self.is_converged():
      top_generation = self.get_fit()
      top_str = "".join(str(top_generation[0]))
      
      print(f"Generation #{generation_number}:\t{top_str}\t{top_generation[1]}")

      specimen_evaluations = self.fitness_all()
      selected_specimen = self.select_specimen(specimen_evaluations)
      
      self.specimen = self.generate_children(selected_specimen)
      
      generation_number += 1
    
    return self.get_fit()

# %% [markdown]
# To run the algorithm:

# %%
class Item:
  def __init__(self, value, weight):
    self.value = value
    self.weight = weight

params = {
    "mutation_percentage": 0.2,
    "select_top": 1,
    "generation_size": 10,
    "fit_threshold": 36,
    "max_generations": 200,
    "max_weight": 15,
    "max_per_item": 5,
    "items": [Item(4, 12), Item(2, 2), Item(2, 1), Item(1, 1), Item(10,4)]
}

knapsack = KnapsackGenetic(params)
knapsack.run()
# Out:
# Generation #1:	[0, 3, 5, 0, 1]	26
# Generation #2:	[5, 3, 1, 4, 0]	1
# Generation #3:	[0, 1, 0, 4, 2]	26
# Generation #4:	[5, 3, 1, 4, 0]	1
# Generation #5:	[5, 4, 0, 3, 4]	1
# Generation #6:	[2, 3, 4, 1, 2]	1
# Generation #7:	[0, 0, 4, 1, 2]	29
# Generation #8:	[5, 3, 0, 2, 3]	1
# Generation #9:	[0, 0, 4, 4, 2]	1
# Generation #10:	[3, 1, 3, 2, 3]	1
# Generation #11:	[0, 1, 0, 0, 2]	22
# Generation #12:	[3, 2, 3, 1, 2]	1
# Generation #13:	[3, 4, 0, 1, 2]	1
# Generation #14:	[5, 1, 3, 3, 1]	1
# Generation #15:	[0, 1, 3, 3, 1]	21
# Generation #16:	[0, 1, 3, 5, 1]	23
# Generation #17:	[3, 3, 3, 1, 1]	1
# Generation #18:	[5, 1, 3, 1, 4]	1
# Generation #19:	[5, 1, 2, 1, 4]	1
# Generation #20:	[0, 1, 3, 4, 0]	12
# Generation #21:	[0, 1, 3, 5, 0]	13
# Generation #22:	[4, 4, 1, 3, 5]	1
# Generation #23:	[5, 4, 1, 4, 3]	1
# Generation #24:	[4, 1, 1, 3, 0]	1
# Generation #25:	[4, 1, 4, 3, 0]	1
# Generation #26:	[0, 3, 2, 4, 5]	1
# Generation #27:	[5, 5, 3, 4, 5]	1
# Generation #28:	[1, 4, 5, 4, 2]	1
# Generation #29:	[1, 5, 3, 4, 0]	1
# Generation #30:	[1, 5, 3, 4, 1]	1
# Generation #31:	[2, 5, 3, 4, 5]	1
# Generation #32:	[4, 1, 2, 5, 3]	1
# Generation #33:	[0, 5, 4, 0, 0]	18
# Generation #34:	[0, 0, 4, 0, 0]	8
# Generation #35:	[2, 4, 3, 1, 3]	1
# Generation #36:	[5, 0, 5, 3, 0]	1
# Generation #37:	[5, 4, 3, 3, 0]	1
# Generation #38:	[0, 5, 4, 4, 5]	1
# Generation #39:	[5, 4, 3, 4, 0]	1
# Generation #40:	[0, 4, 3, 0, 0]	14
# Generation #41:	[5, 4, 2, 4, 0]	1
# Generation #42:	[0, 4, 3, 2, 0]	16
# Generation #43:	[0, 5, 3, 2, 0]	18
# Generation #44:	[0, 5, 3, 2, 0]	18
# Generation #45:	[0, 1, 3, 1, 0]	9
# Generation #46:	[0, 1, 5, 1, 0]	13
# Generation #47:	[0, 1, 5, 5, 0]	17
# Generation #48:	[0, 1, 5, 5, 0]	17
# Generation #49:	[4, 1, 3, 2, 4]	1
# Generation #50:	[0, 1, 3, 2, 1]	20
# Generation #51:	[0, 2, 5, 5, 0]	19
# Generation #52:	[0, 1, 1, 2, 1]	16
# Generation #53:	[1, 2, 5, 5, 3]	1
# Generation #54:	[5, 1, 3, 3, 5]	1
# Generation #55:	[4, 1, 3, 3, 5]	1
# Generation #56:	[2, 1, 3, 3, 4]	1
# Generation #57:	[0, 2, 5, 5, 0]	19
# Generation #58:	[4, 3, 5, 1, 0]	1
# Generation #59:	[2, 4, 3, 1, 4]	1
# Generation #60:	[1, 5, 3, 0, 2]	1
# Generation #61:	[4, 3, 5, 1, 1]	1
# Generation #62:	[1, 5, 4, 0, 2]	1
# Generation #63:	[1, 3, 5, 0, 3]	1
# Generation #64:	[1, 5, 2, 0, 0]	1
# Generation #65:	[1, 5, 0, 3, 4]	1
# Generation #66:	[2, 2, 5, 1, 2]	1
# Generation #67:	[1, 4, 5, 1, 3]	1
# Generation #68:	[2, 1, 1, 0, 5]	1
# Generation #69:	[1, 1, 1, 0, 0]	8
# Generation #70:	[0, 0, 5, 0, 1]	20
# Generation #71:	[0, 0, 2, 0, 1]	14
# Generation #72:	[0, 0, 2, 0, 2]	24
# Generation #73:	[0, 1, 2, 5, 1]	21
# Generation #74:	[0, 1, 1, 0, 2]	24
# Generation #75:	[0, 3, 2, 0, 1]	20
# Generation #76:	[0, 3, 2, 2, 1]	22
# Generation #77:	[0, 3, 2, 1, 1]	21
# Generation #78:	[0, 5, 0, 0, 1]	20
# Generation #79:	[0, 2, 1, 2, 1]	18
# Generation #80:	[4, 4, 3, 5, 1]	1
# Generation #81:	[5, 2, 1, 2, 3]	1
# Generation #82:	[4, 4, 0, 5, 2]	1
# Generation #83:	[4, 4, 5, 4, 3]	1
# Generation #84:	[4, 4, 5, 3, 5]	1
# Generation #85:	[0, 0, 4, 5, 1]	23
# Generation #86:	[0, 0, 4, 5, 1]	23
# Generation #87:	[0, 2, 4, 3, 1]	25
# Generation #88:	[0, 2, 4, 3, 1]	25
# Generation #89:	[0, 2, 4, 0, 1]	22
# Generation #90:	[0, 1, 2, 3, 1]	19
# Generation #91:	[0, 1, 2, 3, 1]	19
# Generation #92:	[4, 1, 2, 3, 1]	1
# Generation #93:	[3, 2, 2, 3, 0]	1
# Generation #94:	[3, 2, 2, 2, 0]	1
# Generation #95:	[4, 3, 5, 3, 1]	1
# Generation #96:	[0, 0, 4, 0, 1]	18
# Generation #97:	[1, 4, 1, 0, 1]	1
# Generation #98:	[1, 0, 5, 3, 2]	1
# Generation #99:	[2, 5, 5, 3, 1]	1
# Generation #100:	[4, 0, 1, 1, 1]	1
# Generation #101:	[2, 5, 1, 4, 1]	1
# Generation #102:	[1, 2, 1, 3, 1]	1
# Generation #103:	[0, 2, 1, 3, 1]	19
# Generation #104:	[4, 1, 1, 3, 3]	1
# Generation #105:	[3, 4, 4, 1, 4]	1
# Generation #106:	[1, 2, 1, 1, 1]	1
# Generation #107:	[2, 2, 1, 1, 1]	1
# Generation #108:	[1, 2, 1, 3, 1]	1
# Generation #109:	[1, 2, 1, 4, 1]	1
# Generation #110:	[1, 3, 3, 2, 1]	1
# Generation #111:	[0, 3, 3, 2, 1]	24
# Generation #112:	[3, 4, 0, 1, 2]	1
# Generation #113:	[2, 2, 2, 3, 1]	1
# Generation #114:	[5, 2, 3, 3, 1]	1
# Generation #115:	[1, 2, 3, 3, 1]	1
# Generation #116:	[5, 4, 2, 4, 5]	1
# Generation #117:	[2, 0, 2, 5, 3]	1
# Generation #118:	[0, 4, 2, 1, 1]	23
# Generation #119:	[0, 4, 2, 0, 1]	22
# Generation #120:	[0, 1, 1, 3, 1]	17
# Generation #121:	[0, 1, 4, 3, 1]	23
# Generation #122:	[0, 1, 4, 3, 1]	23
# Generation #123:	[0, 1, 2, 4, 1]	20
# Generation #124:	[0, 1, 0, 4, 1]	16
# Generation #125:	[3, 1, 1, 0, 5]	1
# Generation #126:	[5, 0, 0, 0, 1]	1
# Generation #127:	[3, 1, 5, 2, 5]	1
# Generation #128:	[3, 1, 4, 4, 2]	1
# Generation #129:	[1, 1, 4, 2, 5]	1
# Generation #130:	[5, 5, 3, 2, 5]	1
# Generation #131:	[3, 5, 4, 1, 2]	1
# Generation #132:	[4, 4, 4, 3, 3]	1
# Generation #133:	[4, 5, 0, 3, 2]	1
# Generation #134:	[2, 1, 4, 2, 3]	1
# Generation #135:	[3, 1, 5, 2, 1]	1
# Generation #136:	[3, 1, 5, 1, 3]	1
# Generation #137:	[0, 1, 3, 2, 3]	1
# Generation #138:	[3, 5, 0, 0, 1]	1
# Generation #139:	[3, 5, 3, 1, 1]	1
# Generation #140:	[4, 2, 4, 2, 3]	1
# Generation #141:	[4, 2, 4, 2, 5]	1
# Generation #142:	[0, 5, 3, 5, 1]	1
# Generation #143:	[4, 2, 0, 0, 3]	1
# Generation #144:	[2, 2, 4, 0, 3]	1
# Generation #145:	[2, 0, 2, 5, 1]	1
# Generation #146:	[5, 5, 0, 0, 5]	1
# Generation #147:	[2, 3, 4, 4, 1]	1
# Generation #148:	[3, 5, 2, 0, 5]	1
# Generation #149:	[0, 5, 2, 0, 1]	1
# Generation #150:	[0, 5, 0, 0, 1]	20
# Generation #151:	[0, 5, 0, 0, 1]	20
# Generation #152:	[0, 5, 0, 0, 1]	20
# Generation #153:	[0, 0, 2, 3, 2]	27
# Generation #154:	[3, 0, 2, 2, 1]	1
# Generation #155:	[0, 5, 0, 3, 0]	13
# Generation #156:	[0, 5, 0, 2, 0]	12
# Generation #157:	[0, 5, 0, 5, 0]	15
# Generation #158:	[0, 2, 0, 1, 0]	5
# Generation #159:	[0, 1, 2, 4, 1]	20
# Generation #160:	[3, 5, 4, 1, 3]	1
# Generation #161:	[5, 5, 4, 1, 1]	1
# Generation #162:	[0, 5, 1, 1, 0]	13
# Generation #163:	[2, 0, 1, 4, 1]	1
# Generation #164:	[1, 1, 0, 4, 1]	1
# Generation #165:	[1, 2, 2, 2, 2]	1
# Generation #166:	[0, 2, 3, 3, 0]	13
# Generation #167:	[5, 5, 5, 0, 1]	1
# Generation #168:	[0, 2, 2, 3, 0]	11
# Generation #169:	[0, 0, 5, 0, 1]	20
# Generation #170:	[0, 4, 2, 3, 0]	15
# Generation #171:	[0, 4, 3, 3, 0]	17
# Generation #172:	[3, 2, 4, 1, 1]	1
# Generation #173:	[2, 4, 3, 4, 0]	1
# Generation #174:	[2, 5, 5, 2, 0]	1
# Generation #175:	[2, 1, 3, 4, 4]	1
# Generation #176:	[4, 2, 4, 3, 0]	1
# Generation #177:	[2, 5, 0, 4, 4]	1
# Generation #178:	[2, 2, 3, 4, 1]	1
# Generation #179:	[5, 4, 1, 4, 4]	1
# Generation #180:	[4, 4, 3, 5, 4]	1
# Generation #181:	[3, 4, 2, 4, 1]	1
# Generation #182:	[5, 4, 2, 0, 1]	1
# Generation #183:	[3, 3, 3, 5, 1]	1
# Generation #184:	[2, 3, 3, 5, 3]	1
# Generation #185:	[0, 0, 2, 0, 3]	34
# ([0, 0, 3, 0, 3], 36)
